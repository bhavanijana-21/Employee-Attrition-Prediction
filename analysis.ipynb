# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("HR_Attrition.csv")
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df["Attrition"].head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: str

# %%
df["Attrition"].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
attrition_rate = df["Attrition"].value_counts(normalize=True) * 100
print(attrition_rate)
# Out:
# Attrition
# No     83.877551
# Yes    16.122449
# Name: proportion, dtype: float64

# %%
numeric_columns = df.select_dtypes(include=np.number).columns
categorical_columns = df.select_dtypes(include='object').columns

print("Numeric Columns:", len(numeric_columns))
print("Categorical Columns:", len(categorical_columns))
# Out:
# Numeric Columns: 26
# Categorical Columns: 9
# C:\Users\HP\AppData\Local\Temp\ipykernel_56964\4056419803.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include='object').columns

# %% [markdown]
# ### Observation
#
# - The dataset contains 1470 employee records and 35 features.
# - The target variable is Attrition.
# - Approximately 16% of employees left the company, while about 84% stayed.
# - The dataset is imbalanced because employees who stayed greatly outnumber those who left.
# - No missing values are present in the dataset.

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df = df.drop(['EmployeeNumber', 'Over18', 'StandardHours'], axis=1)

# %%
df["Attrition"] = df["Attrition"].map({
    "Yes": 1,
    "No": 0
})

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

categorical_columns = df.select_dtypes(include='object').columns

print(categorical_columns)
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'OverTime'],
#       dtype='str')
# C:\Users\HP\AppData\Local\Temp\ipykernel_56964\3656628698.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include='object').columns

# %%
df = pd.get_dummies(
    df,
    columns=categorical_columns,
    drop_first=True
)

# %%
X = df.drop("Attrition", axis=1)

y = df["Attrition"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
print("Features Shape:", X_scaled.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (1470, 45)
# Target Shape: (1470,)

# %% [markdown]
# # Task 3: Exploratory Data Analysis (EDA)

# %%
original_df = pd.read_csv("HR_Attrition.csv")

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=original_df,
    x="Department",
    hue="Attrition"
)

plt.title("Attrition by Department")
plt.xticks(rotation=15)
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=original_df,
    y="JobRole",
    hue="Attrition"
)

plt.title("Attrition by Job Role")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=original_df,
    x="Attrition",
    y="MonthlyIncome"
)

plt.title("Monthly Income vs Attrition")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=original_df,
    x="WorkLifeBalance",
    hue="Attrition"
)

plt.title("Work-Life Balance vs Attrition")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    data=original_df,
    x="YearsAtCompany",
    hue="Attrition",
    multiple="stack"
)

plt.title("Years at Company vs Attrition")
plt.show()

# %% [markdown]
# ### Business Insights
#
# 1. The Sales department has a higher number of employees leaving compared to other departments.
# 2. Sales Representatives and Laboratory Technicians show relatively higher attrition.
# 3. Employees with lower monthly income are more likely to leave the company.
# 4. Employees reporting lower work-life balance tend to have higher attrition.
# 5. Most employees who leave have fewer years at the company, indicating attrition is higher in the early stages of employment.

# %% [markdown]
# # Task 4: Model Building & Comparison

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print("Training Data:", X_train.shape)
print("Testing Data:", X_test.shape)
# Out:
# Training Data: (1176, 45)
# Testing Data: (294, 45)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(class_weight='balanced', random_state=42)

lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    class_weight='balanced',
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=42)

gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
print("All models trained successfully!")
# Out:
# All models trained successfully!

# %% [markdown]
# # Task 5: Model Evaluation

# %%
lr_pred = lr.predict(X_test)

rf_pred = rf.predict(X_test)

gb_pred = gb.predict(X_test)

# %%
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    roc_auc_score
)

# %%
print("Logistic Regression Accuracy:",
      accuracy_score(y_test, lr_pred))

print(classification_report(y_test, lr_pred))
# Out:
# Logistic Regression Accuracy: 0.717687074829932
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       255
#            1       0.26      0.59      0.36        39
#
#     accuracy                           0.72       294
#    macro avg       0.59      0.66      0.59       294
# weighted avg       0.83      0.72      0.76       294

# %%
print("Random Forest Accuracy:",
      accuracy_score(y_test, rf_pred))

print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.8503401360544217
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       255
#            1       0.38      0.21      0.27        39
#
#     accuracy                           0.85       294
#    macro avg       0.63      0.58      0.59       294
# weighted avg       0.82      0.85      0.83       294

# %%
print("Gradient Boosting Accuracy:",
      accuracy_score(y_test, gb_pred))

print(classification_report(y_test, gb_pred))
# Out:
# Gradient Boosting Accuracy: 0.8673469387755102
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93       255
#            1       0.50      0.18      0.26        39
#
#     accuracy                           0.87       294
#    macro avg       0.69      0.58      0.60       294
# weighted avg       0.83      0.87      0.84       294

# %%
print("Logistic Regression ROC-AUC:",
      roc_auc_score(y_test, lr.predict_proba(X_test)[:,1]))

print("Random Forest ROC-AUC:",
      roc_auc_score(y_test, rf.predict_proba(X_test)[:,1]))

print("Gradient Boosting ROC-AUC:",
      roc_auc_score(y_test, gb.predict_proba(X_test)[:,1]))
# Out:
# Logistic Regression ROC-AUC: 0.7659125188536954
# Random Forest ROC-AUC: 0.7661136249371543
# Gradient Boosting ROC-AUC: 0.7792860734037205

# %% [markdown]
# | Model               |   Accuracy |    ROC-AUC |
# | ------------------- | ---------: | ---------: |
# | Logistic Regression | **71.09%** | **0.7600** |
# | Random Forest       | **85.03%** | **0.7661** |
# | Gradient Boosting   | **86.73%** | **0.7792** |

# %% [markdown]
# # Task 6: Visualization

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, gb_pred)

plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')

plt.title("Confusion Matrix - Gradient Boosting")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": gb.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(10)
# Out:
#                     Feature  Importance
# 10            MonthlyIncome    0.134218
# 44             OverTime_Yes    0.128761
# 0                       Age    0.067914
# 16         StockOptionLevel    0.047636
# 8                  JobLevel    0.047368
# 17        TotalWorkingYears    0.040604
# 7            JobInvolvement    0.038575
# 2          DistanceFromHome    0.037888
# 1                 DailyRate    0.037085
# 5   EnvironmentSatisfaction    0.033521

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features")

plt.show()

# %%
from sklearn.metrics import roc_curve

plt.figure(figsize=(8,6))

for model, label in [
    (lr, "Logistic Regression"),
    (rf, "Random Forest"),
    (gb, "Gradient Boosting")
]:
    probs = model.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, probs)
    plt.plot(fpr, tpr, label=label)

plt.plot([0,1],[0,1],'k--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")

plt.legend()

plt.show()

# %%
importance.head(10)
# Out:
#                     Feature  Importance
# 10            MonthlyIncome    0.134218
# 44             OverTime_Yes    0.128761
# 0                       Age    0.067914
# 16         StockOptionLevel    0.047636
# 8                  JobLevel    0.047368
# 17        TotalWorkingYears    0.040604
# 7            JobInvolvement    0.038575
# 2          DistanceFromHome    0.037888
# 1                 DailyRate    0.037085
# 5   EnvironmentSatisfaction    0.033521

# %% [markdown]
# ### Observation
#
# The feature importance analysis shows that Monthly Income and Overtime are the two strongest predictors of employee attrition. Age, Job Level, and Total Working Years also have a significant impact on predicting whether an employee is likely to leave the company. These insights can help HR identify high-risk employees and implement targeted retention strategies.
